# %% [markdown]
# # Flexbox in CSS

# %% [markdown]
# 1. Describe the main differences between the CSS Flexbox layout model and the CSS Grid layout model. When would you choose to use one over the other?
#    - The basic difference between CSS grid layout and CSS flexbox layout is that flexbox was designed for layout in one dimension - either a row or a column. Grid was designed for two-dimensional layout - rows, and columns at the same time. The two specifications both use CSS box alignment features.
#    - CSS grid layout is designed to work alongside other parts of CSS, as part of a complete system for doing the layout.
# 2. Explain the role of the following key properties in the Flexbox layout model
#    1.   justify-content
#    2.   align-item
#    3.   gap
#    4.   flex-direction
#    5.   flex-wrap
#
#   *Justify Content* :
#    *   Aligns the entire flex container's items along the main axis.
#    *   Possible values: flex-start, flex-end, center, space-between, space-around, space-evenly.
#    *   Determines how space is distributed around items.
#
#   *Align Items* :
#    *   Aligns flex items along the cross-axis.
#    *   Possible values: stretch, center, flex-start, flex-end.
#    *   The default value is stretch.
#
#   *Gap* :
#    *   Sets the spacing between items in a flex container.
#    *   Can be defined for rows (row-gap) and columns (column-gap), or both (gap).
#    *   Useful for creating consistent spacing without margins.
#
#   *Flex Direction* :
#    *   Specifies the direction of the flex items in the flex container.
#    *   Possible values: row, row-reverse, column, column-reverse.
#    *   Determines the main axis direction (horizontal or vertical).
#
#   *Flex Wrap* :
#    *   Controls whether flex items are forced into a single line or can wrap onto multiple lines.
#    *   Possible values: nowrap, wrap, wrap-reverse.
#    *   The default value is nowrap.

# %%
# 3. Write the code to center a div using CSS Flexbox.
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="style (3).css">
</head>
<body>
    <div></div>
</body>
</html>

# %%
div {
    height: 400px;
    width: 400px;
    background-color: green;
}

body {
    display: flex;
    justify-content: center;
    align-items: center;
    min-height: 100vh;
    margin: 0;
}

# %%
# 4. A client of yours wants to add a pricing section on their website to showcase their newly introduced premium plans.
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="style (4).css">
</head>
<body>
    <section>
        <div id="pricingcard_one">
            <div id="carddetail1_one">dheader_one">
                        <div id="headername_one">
                            <div id="frame1_one">
                                <header id="text1_one">Free Plan</header>
                            </div>
                            <div id="frame2_one">
                                <header id="text2_one">For personal</header>
                            </div>
                        </div>
                        <div id="prize_one">
                            <header id="text3_one">$0</header>
                        </div>
                    </div>
                    <div id="plandetails_one">
                        <div id="group1_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text4_one">1 users</header>
                            </div>
                        </div>
                        <div id="group2_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text5_one">4 Web mails</header>
                            </div>
                        </div>
                        <div id="group3_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text6_one">Responsive Website</header>
                            </div>
                        </div>
                        <div id="group4_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text7_one">Free SSL</header>
                            </div>
                        </div>
                    </div>
                </div>
                <div id="subscribebutton_one">
                    <div id="text8_one">Subscribe now</div>
                </div>
            </div>
        </div>


        <div id="pricingcard_two">
            <div id="carddetail1_one">
                <div id="carddetails2_one">
                    <div id="cardheader_one">
                        <div id="headername_one">
                            <div id="frame1_one">
                                <header id="text1_two">Basic Plan</header>
                            </div>
                            <div id="frame2_two">
                                <header id="text2_two">For small business</header>
                            </div>
                        </div>
                        <div id="prize_one">
                            <header id="text3_two">$29</header>
                        </div>
                    </div>
                    <div id="plandetails_three">
                        <div id="group1_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1 (1).png">
                            </div>
                            <div id="frame7_three">
                                <header id="text4_two">4 users</header>
                            </div>
                        </div>
                        <div id="group2_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1 (1).png">
                            </div>
                            <div id="frame7_one">
                                <header id="text5_two">10 Web mails</header>
                            </div>
                        </div>
                        <div id="group3_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1 (1).png">
                            </div>
                            <div id="frame7_one">
                                <header id="text6_two">Responsive Website</header>
                            </div>
                        </div>
                        <div id="group4_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1 (1).png">
                            </div>
                            <div id="frame7_one">
                                <header id="text7_two">Free SSL</header>
                            </div>
                        </div>
                    </div>
                </div>
                <div id="subscribebutton_two">
                    <div id="text8_two">Subscribe now</div>
                </div>
            </div>

        </div>

        <div id="pricingcard_three">
            <div id="carddetail1_one">
                <div id="carddetails2_one">
                    <div id="cardheader_one">
                        <div id="headername_one">
                            <div id="frame1_one">
                                <header id="text1_one">Pro Plan</header>
                            </div>
                            <div id="frame2_one">
                                <header id="text2_one">For enterprise</header>
                            </div>
                        </div>
                        <div id="prize_one">
                            <header id="text3_one">$49</header>
                        </div>
                    </div>
                    <div id="plandetails_three">
                        <div id="group1_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_three">
                                <header id="text4_three">unlimited users</header>
                            </div>
                        </div>
                        <div id="group2_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text5_three">Unlimited Web mails</header>
                            </div>
                        </div>
                        <div id="group3_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text6_one">Responsive Website</header>
                            </div>
                        </div>
                        <div id="group4_one">
                            <div id="frame6_one">
                                <img class="tick" src="check-mark 1.png">
                            </div>
                            <div id="frame7_one">
                                <header id="text7_three">Free SSL + SEO</header>
                            </div>
                        </div>
                    </div>
                </div>
                <div id="subscribebutton_one">
                    <div id="text8_one">Subscribe now</div>
                </div>
            </div>
        </div>
    </section>

</body>
</html>

# %%
body {
            display: flex;
            justify-content: space-evenly;
            align-items: center;
            min-height: 100vh;
            margin: 0;
        }
        section {
            width: 962px;
            height: 427px;
            gap: 32px;
            top: 25px;
            left: -8px;
            padding-top: 32px;
            padding-right: 48px;
            padding-bottom: 32px;
            padding-left: 48px;
            background: #F4F2FD;
            display: flex;
            justify-content: space-evenly;
            align-items: center;
        }

        #pricingcard_one {
            width: 262px;
            height: 363px;
            border-radius: 8px;
            padding: 32px;
            gap: 32px;
            background: #FFFFFF;
            box-shadow: 0px 1px 10px 0px #00000040;
        }

        #pricingcard_two {
            width: 262px;
            height: 363px;
            border-radius: 8px;
            padding: 32px;
            gap: 32px;
            background: #202842;
            box-shadow: 0px 1px 10px 0px #00000040;
        }

        #pricingcard_three {
            width: 263px;
            height: 361px;
            border-radius: 8px;
            padding: 32px;
            gap: 32px;
            background: #FFFFFF;
            box-shadow: 0px 1px 10px 0px #00000040;
        }

        #carddetails1_one {
            width: 198px;
            height: 306px;
            gap: 32px;
        }

        #carddetails2_one {
            width: 198px;
            height: 236px;
            gap: 16px;
        }

        #cardheader_one {
            width: 198px;
            height: 108px;
            gap: 16px;
        }

        #headername_one {
            width: 157px;
            height: 56px;
        }

        #frame1_one {
            width: 157px;
            height: 40px;
            /* padding-top: 4px; */
            padding-right: 8px;
            /* padding-bottom: 4px; */
            padding-left: 8px;
        }

        #text1_one {
            width: 141px;
            height: 32px;
            font-family: Nunito;
            font-weight: 700px;
            font-size: 32px;
            line-height: 32px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text1_two {
            width: 141px;
            height: 32px;
            font-family: Nunito;
            font-weight: 700px;
            font-size: 32px;
            line-height: 32px;
            letter-spacing: 0%;
            color:#FFFFFF;
;
        }

        #frame2_one {
            width: 107px;
            height: 16px;
            padding-right: 8px;
            padding-left: 8px;
            gap: 10px;
        }

        #text2_one {
            width: 91px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

         #frame2_two {
            width: 151px;
            height: 16px;
            padding-right: 8px;
            padding-left: 8px;
            gap: 10px;
        }

        #text2_two {
            width: 135px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

        #prize_one {
            width: 58px;
            height: 36px;
            padding-right: 8px;
            padding-left: 8px;
            margin-top: 20px;
            gap: 10px;
        }

        #text3_one {
            width: 42px;
            height: 36px;
            font-family: Sans Serif Collection;
            font-weight: 400px;
            font-size: 36px;
            line-height: 36px;
            letter-spacing: 0%;
            color: #202842;
        }

         #text3_two {
            width: 42px;
            height: 36px;
            font-family: Sans Serif Collection;
            font-weight: 400px;
            font-size: 36px;
            line-height: 36px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

         #plandetails_one {
            margin-top: 20px;
            width: 198px;
            height: 112px;
            padding-left: 8px;
        }

        #plandetails_three {
            margin-top: 20px;
            width: 203px;
            height: 112px;
            padding-left: 8px;

        }

        #group1_one {
            width: 95px;
            height: 28px;
            display: flex;
        }

        #group2_one {
            width: 134px;
            height: 28px;
            display: flex;
        }

        #group3_one {
            width: 190px;
            height: 28px;
            display: flex;
        }

        #group4_one {
            width: 107px;
            height: 28px;
            display: flex;
        }

        #frame6_one {
            width: 30;
            height: 28;
            top: 84px;
            left: 8px;
            padding-top: 3px;
            padding-right: 4px;
            padding-bottom: 3px;
            padding-left: 4px;
            gap: 10px;
        }

        .tick {
            width: 22px;
            height: 22px;
        }

        #frame7_one {
            width: 65px;
            height: 28px;
            left: 38px;
            padding-top: 8px;
            padding-right: 8px;
            padding-bottom: 4px;
            padding-left: 4px;
            gap: 10px;
        }

        #frame7_three {
            width: 195px;
            height: 28px;
            left: 38px;
            padding-top: 8px;
            padding-right: 8px;
            padding-bottom: 4px;
            padding-left: 4px;
            gap: 10px;
        }

        #text4_one {
            width: 53px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text4_two {
            width: 53px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

         #text4_three {
            width: 114px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text5_one {
            width: 92px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text5_two {
            width: 92px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

         #text5_three {
            width: 153px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text6_one {
            width: 148px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

         #text6_two {
            width: 148px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

        #text7_one {
            width: 65px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text7_two {
            width: 65px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

        #text7_three {
            width: 114px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #202842;
        }

        #text7_two {
            width: 114px;
            height: 16px;
            font-family: Nunito;
            font-weight: 500px;
            font-size: 16px;
            line-height: 16px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

        #subscribebutton_one {
            width: 156px;
            height: 38px;
            border-radius: 50px;
            gap: 10px;
            padding-top: 8px;
            padding-right: 24px;
            padding-bottom: 8px;
            padding-left: 24px;
            background: #202842;
            margin-top: 50px;
            display: flex;
            justify-content: space-evenly;
            align-items: center;
        }

        #subscribebutton_two {
            width: 156px;
            height: 38px;
            border-radius: 50px;
            gap: 10px;
            padding-top: 8px;
            padding-right: 24px;
            padding-bottom: 8px;
            padding-left: 24px;
            background: #FFFFFF;
            margin-top: 50px;
            display: flex;
            justify-content: space-evenly;
            align-items: center;
        }

        #text8_one {
            width: 108px;
            height: 22px;
            font-family: Nunito;
            font-weight: 600px;
            font-size: 16px;
            line-height: 22px;
            letter-spacing: 0%;
            color: #FFFFFF;
        }

        #text8_two {
            width: 108px;
            height: 22px;
            font-family: Nunito;
            font-weight: 600px;
            font-size: 16px;
            line-height: 22px;
            letter-spacing: 0%;
            color: #202842;
        }

# %%
# 5. build a clone of the IRCTC Ticket booking page.
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="style (5).css">
</head>
<body>
    <section id="irctcscreen">
        <div id="menu">
            <div id="frame5">
                <div id="group4">
                    <a id="text1" href="">Ask Disha</a>
                </div>
                <div id="group5">
                    <a id="text2" href="">Contact us</a>
                </div>
                <div id="group6">
                    <a id="text3" href="">Alerts</a>
                </div>
            </div>
            <div id="frame6">
                <div id="frame1">
                    <a id="text4" href="">Login</a>
                </div>
                <div id="frame2">
                    <a id="text5" href="">Register</a>
                </div>
                <div id="frame3">
                    <a id="text6" href="">Agent login</a>
                </div>
            </div>
        </div>
        <button id="rectangle9" type="submit" form="">
            <span id="text7">Search Train</span>
            <img id="arrow" src="arrow_forward_FILL0_wght400_GRAD0_opsz48 1@2x.png">
        </button>
        <div id="imagediv">
            <img id="rectangle11" src="image.png">
        </div>
        <div id="logo">
            <img id="irctclogo" src="image 5 (1).png">
            <img id="irlogo" src="image 6 (1).png">
        </div>
        <div id="headertitle">
            <div id="text19">Indian Railways</div>
            <span id="text20">Safety</span>
            <span id="text21">Security</span>
            <span id="text22">Punctuality</span>
        </div>
        <div id="subbutton">
            <div id="frame_1">
                <img id="confirmationicon" src="confirmation_number_FILL0_wght400_GRAD0_opsz48 1.png">
                <span id="text16">BOOK Ticket</span>
            </div>
            <div id="frame_2">
                <img id="confirmationicon" src="done_FILL0_wght400_GRAD0_opsz48 (1) 1.png">
                <span id="text17">PNR Status</span>
            </div>
            <div id="frame_3">
                <img id="charticon" src="insert_chart_FILL0_wght400_GRAD0_opsz48 1.png">
                <span id="text18">charts / vacancy</span>
            </div>
        </div>
        </div>
        <div id="searchtrain1">
            <img id="fromicon" src="ic-search-from-desktop.png">
            <div>
                <div>
                    <span id="text8">From</span>
                    <img class="vectoricon" src="expand_more_FILL0_wght400_GRAD0_opsz48 4.png">
                </div>
                <div id="text9">Bangalore</div>
                <div id="text15">KSR - Bangalore</div>
            </div>
            <img id="syncicon" src="sync_alt_FILL0_wght300_GRAD0_opsz48 1.png">
            <img id="toicon" src="ic-search-to-desktop.png">
            <div>
                <div>
                    <span id="text8">To</span>
                    <img class="vectoricon" src="expand_more_FILL0_wght400_GRAD0_opsz48 4.png">
                </div>
                <div id="text9">Howrah Jn</div>
                <div id="text15">HWH - Howrah</div>
            </div>
        </div>
        <div id="searchtrain">
            <img id="dateicon" src="ic-search-calender-desktop.png">
            <div>
                <div>
                    <span id="text8">Date</span>
                    <img class="vectoricon" src="expand_more_FILL0_wght400_GRAD0_opsz48 4.png">
                </div>
                <div id="text9">01 Aug 25</div>
                <div id="text10">Tuesday</div>
            </div>
            <img id="classicon" src="group_work_FILL0_wght200_GRAD0_opsz48 1.png">
            <div>
                <div>
                    <span id="text11">Class</span>
                    <img class="vectoricon" src="expand_more_FILL0_wght400_GRAD0_opsz48 4.png">
                </div>
                <div id="text12">3A</div>
                <div id="text13">AC 3 Tier</div>
            </div>
            <img id="seattypeicon" src="widgets_FILL0_wght200_GRAD0_opsz48 1.png">
            <div>
                <div>
                    <span id="text11">Seat Type</span>
                    <img class="vectoricon" src="expand_more_FILL0_wght400_GRAD0_opsz48 4.png">
                </div>
                <div id="text14">TATKAL</div>
                <div id="text13">AC 3 Tier</div>
            </div>
        </div>
    </section>
</body>
</html>

# %%
body {
    width: 1469px;
    height: 1143px;
    top: -938px;
    left: 1590px;
}

#irctcscreen {
    width: 1460px;
    height: 1100px;
    left: 5px;
    background: #FFFFFF;
}

#menu {
    width: 321.8055419921875px;
    height: 68.87499237060547px;
    padding-top: 63.69px;
    padding-left: 398.46px;
    position: absolute;
}

#frame5 {
    width: 246.69444274902344px;
    height: 18px;
    top: 63.69px;
    left: 398.49px;
    gap: 25.35px;
    display: flex;
}

#group4 {
    width: 72px;
    height: 18px;
    color: #333333;
}

#text1 {
    width: 72px;
    height: 18px;
    font-family: Inter;
    font-weight: 500px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-align: center;
    color: #333333;
    text-decoration: none;
}

#group5 {
    width: 80px;
    height: 18px;
    color: #333333;
    display: flex;
    justify-content: space-evenly;
    align-items: center;
}

#text2 {
    width: 80px;
    height: 18px;
    left: 97.35px;
    font-family: Inter;
    font-weight: 500px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-align: center;
    color: #333333;
    text-decoration: none;
}

#group6 {
    width: 44px;
    height: 18px;
    color: #333333;
    display: flex;
    justify-content: space-evenly;
    align-items: center;
}

#text3 {
    width: 44px;
    height: 18px;
    left: 202.69px;
    font-family: Inter;
    font-weight: 500px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-align: center;
    color: #333333;
    text-decoration: none;
}

#frame6 {
    width: 321.8055419921875px;
    height: 38.27777862548828px;
    top: 94.29px;
    left: 398.46px;
    gap: 20.28px;
    padding-top: 20px;
    display: flex;
}

#frame1 {
    width: 71.41666412353516px;
    height: 38.27777862548828px;
    gap: 10.14px;
    border-radius: 5.07px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    background: #FB792B;
    display: flex;
    justify-content: center;
    align-items: center;
}

#text4 {
    width: 41px;
    height: 18px;
    font-family: Inter;
    font-weight: 500;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #FFFFFF;
    text-decoration: none;
    justify-content: center;
}

#frame2 {
    width: 91.41666412353516px;
    height: 38.27777862548828px;
    border-radius: 5.07px;
    border-width: 1.01px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    gap: 10.14px;
    background: #FFFFFF;
    border: 1.01px solid #33333333;
    display: flex;
    justify-content: center;
    align-items: center;
}

#text5 {
    width: 61px;
    height: 18px;
    font-family: Inter;
    font-weight: 500px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #333333;
    text-decoration: none;
}

#frame3 {
    width: 118.41666412353516px;
    height: 38.27777862548828px;
    border-radius: 5.07px;
    border-width: 1.01px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    gap: 10.14px;
    background: #FFFFFF;
    border: 1.01px solid #33333333;
    display: flex;
    justify-content: center;
    align-items: center;
}

#text6 {
    width: 88px;
    height: 18px;
    font-family: Inter;
    font-weight: 500px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #333333;
    text-decoration: none;
}

#rectangle9 {
    width: 618.4722290039062px;
    height: 81.11111450195312px;
    margin-top: 828.56px;
    margin-left: 101.39px;
    border-radius: 10.14px;
    background: #01BB0A;
    position: absolute;
    display: flex;
    justify-content: center;
    align-items: center;
    border: none;
}

#arrow {
    width: 30.41666603088379px;
    height: 30.41666603088379px;
    top: 854.9px;
    left: 485.65px;
}

#text7 {
    width: 160px;
    height: 31px;
    top: 854.9px;
    left: 305.18px;
    font-family: Inter;
    font-weight: 900px;
    font-size: 25.35px;
    line-height: 100%;
    letter-spacing: 0%;
    text-align: center;
    text-transform: capitalize;
    color: #FFFFFF;
    text-decoration: none;
}

#searchtrain {
    width: 618.4722290039062px;
    height: 116.59722137451172px;
    margin-top: 654.97px;
    margin-left: 101.39px;
    border: 1.01px solid #3333331A;
    position: absolute;
    display: flex;
    justify-content: space-evenly;
    align-items: center;
}

#dateicon {
    width: 32.44444274902344px;
    height: 31.059825897216797px;
    top: 694.73px;
    left: 120.67px;
}

/* .vectoricon {
    width: 9.610821723937988px;
    height: 5.449652671813965px;
    top: 7.29px;
    left: 5.32px;
    color: #213D77;
} */

#text8 {
    width: 34px;
    height: 18px;
    top: 675.25px;
    left: 164.25px;
    opacity: 0.8;
    font-family: Inter;
    font-weight: 400px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#text9 {
    width: 126px;
    height: 31px;
    top: 697.56px;
    left: 164.25px;
    font-family: Inter;
    font-weight: 700px;
    font-size: 25.35px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#text10 {
    width: 61px;
    height: 18px;
    top: 733.04px;
    left: 164.25px;
    opacity: 0.8;
    font-family: Inter;
    font-weight: 400;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#text11 {
    width: 40px;
    height: 18px;
    top: 675.25px;
    left: 377.17px;
    opacity: 0.8;
    font-family: Inter;
    font-weight: 400px;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#text12 {
    width: 36px;
    height: 31px;
    top: 697.56px;
    left: 377.17px;
    font-family: Inter;
    font-weight: 700px;
    font-size: 25.35px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#text13 {
    width: 67px;
    height: 18px;
    top: 733.04px;
    left: 377.17px;
    opacity: 0.8;
    font-family: Inter;
    font-weight: 400;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#classicon {
    width: 32.44444274902344px;
    height: 31.059825897216797px;
    top: 694.87px;
    left: 323.44px;
}

#seattypeicon {
    width: 32.44444274902344px;
    height: 31.059825897216797px;
    top: 693.82px;
    left: 526.22px;
}

#text14 {
    width: 100px;
    height: 31px;
    top: 697.56px;
    left: 575.89px;
    font-family: Inter;
    font-weight: 700;
    font-size: 25.35px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#searchtrain1 {
    width: 618.4722290039062px;
    height: 116.59722137451172px;
    margin-top: 518.1px;
    margin-left: 101.39px;
    border: 1.01px solid #3333331A;
    position: absolute;
    display: flex;
    justify-content: space-evenly;
    align-items: center;
}

#fromicon {
    width: 32.44444274902344px;
    height: 32.44444274902344px;
    top: 563.72px;
    left: 121.67px;
}

#toicon {
    width: 32.44444274902344px;
    height: 32.44444274902344px;
    top: 559.67px;
    left: 455.24px;
}

#syncicon {
    width: 48.66666793823242px;
    height: 48.66666793823242px;
    top: 552.57px;
    left: 360.29px;
    border-radius: 50.69px;
}

#text15 {
    width: 118px;
    height: 18px;
    top: 596.17px;
    left: 164.25px;
    opacity: 0.8;
    font-family: Inter;
    font-weight: 400;
    font-size: 15.21px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#subbutton {
    width: 603.2222290039062px;
    height: 44.61111068725586px;
    top: 422.79px;
    left: 101.39px;
    gap: 20.28px;
    position: absolute;
    display: flex;
}

#frame_1 {
    width: 178.88888549804688px;
    height: 44.61111068725586px;
    border-radius: 5.07px;
    gap: 10.14px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    background: #213D77;
}

#confirmationicon {
    width: 24.33333396911621px;
    height: 24.33333396911621px;
}

#text16 {
    width: 114px;
    height: 22px;
    font-family: Inter;
    font-weight: 700;
    font-size: 18.25px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #FFFFFF;
}

#frame_2 {
    width: 164.88888549804688px;
    height: 44.61111068725586px;
    border-radius: 5.07px;
    gap: 10.14px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    border-width: 1.01px;
    background: #FFFFFF;
    border: 1.01px solid #33333380;
}

#frame_3 {
    width: 218.88888549804688px;
    height: 44.61111068725586px;
    border-radius: 5.07px;
    gap: 10.14px;
    padding-top: 10.14px;
    padding-right: 15.21px;
    padding-bottom: 10.14px;
    padding-left: 15.21px;
    border-width: 1.01px;
    background: #FFFFFF;
    border: 1.01px solid #33333380;
}

#charticon {
    width: 24.33333396911621px;
    height: 24.33333396911621px;
}

#text17 {
    width: 100px;
    height: 22px;
    font-family: Inter;
    font-weight: 700px;
    font-size: 18.25px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #333333;
}

#text18 {
    width: 154px;
    height: 22px;
    font-family: Inter;
    font-weight: 700px;
    font-size: 18.25px;
    line-height: 100%;
    letter-spacing: 0%;
    text-transform: capitalize;
    color: #333333;
}

#headertitle {
    width: 438px;
    height: 118.0833511352539px;
    top: 223.06px;
    left: 101.39px;
    position: absolute;
}

#text19 {
    width: 370px;
    height: 59px;
    top: 223.06px;
    left: 101.39px;
    font-family: Inter;
    font-weight: 700px;
    font-size: 48.67px;
    line-height: 100%;
    letter-spacing: 0%;
    color: #333333;
}

#text20 {
    width: 438px;
    height: 39px;
    top: 302.14px;
    left: 101.39px;
    font-family: Inter;
    font-weight: 500;
    font-size: 32.44px;
    line-height: 100%;
    letter-spacing: 0%;
    color: green;
    margin-right: 15px;
}

#text21 {
    width: 438px;
    height: 39px;
    top: 302.14px;
    left: 101.39px;
    font-family: Inter;
    font-weight: 500;
    font-size: 32.44px;
    line-height: 100%;
    letter-spacing: 0%;
    color: orange;
    margin-right: 15px;
}

#text22 {
    width: 438px;
    height: 39px;
    top: 302.14px;
    left: 101.39px;
    font-family: Inter;
    font-weight: 500;
    font-size: 32.44px;
    line-height: 100%;
    letter-spacing: 0%;
    color: blue;
}

#logo {
    width: 168.30555725097656px;
    height: 81.11111450195312px;
    top: 50.69px;
    left: 101.39px;
    position: absolute;
}

#irctclogo {
    width: 66.91666412353516px;
    height: 81.11111450195312px;
    top: 50.69px;
    left: 101.39px;
    margin-right: 15px;
}

#irlogo {
    width: 81.11111450195312px;
    height: 81.11111450195312px;
    top: 50.69px;
    left: 188.58px;
}

#imagediv {
    width: 696px;
    height: 1100px;
    left: 764px;
    position: absolute;
}

#rectangle11 {
    width: 696px;
    height: 1100px;
    left: 764px;
}
